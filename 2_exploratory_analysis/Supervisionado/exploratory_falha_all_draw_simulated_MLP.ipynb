# %%
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import dill
from typing import List
import scipy.stats as sts
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import util
from pathlib import Path
from class_manipulates_path import ManipulatePath
from class_preprocessing_refactor import Preprocessing
from class_format_data import FormatData
util.init()

current_path = sys.path[0]

# %%
def plot_variable(df, column_name, intervalos=None):
    """
    Plota um gráfico de dispersão para uma variável de um DataFrame.

    Parâmetros:
        - df: DataFrame pandas contendo os dados.
        - column_name: Nome da coluna que você deseja plotar.
        - intervalos: Lista de intervalos para plotar linhas verticais.
    """
    plt.figure(figsize=(20, 10))
    plt.scatter(df.index.values, df[column_name].values, color='darkcyan', alpha=0.5)
    plt.xlabel('Índice')
    plt.ylabel(column_name)
    plt.title(f'Gráfico de dispersão para a variável "{column_name}"')


    # Plotar linhas verticais para cada intervalo
    if intervalos:
        for intervalo in intervalos:
            plt.axvline(x=intervalo, linestyle='--', color='red')

    plt.show()

# %%
def class_and_file_generator(data_path, real=False, simulated=False, drawn=False):
    for class_path in data_path.iterdir():
        if class_path.is_dir():
            class_code = int(class_path.stem)
            for instance_path in class_path.iterdir():
                if (instance_path.suffix == '.csv'):
                    if (simulated and instance_path.stem.startswith('SIMULATED')) or \
                       (drawn and instance_path.stem.startswith('DRAWN')) or \
                       (real and (not instance_path.stem.startswith('SIMULATED')) and \
                       (not instance_path.stem.startswith('DRAWN'))):
                        yield class_code, instance_path

# %%
manipulate_path = ManipulatePath()

preprocessing = Preprocessing()

format_data = FormatData()

path_raw_data = manipulate_path.get_path_raw_data()

abnormal_classes_codes = [1, 2, 5, 6, 7, 8]

# %%
# Gets all real instances but maintains only those with any type of undesirable event
real_instances = pd.DataFrame(class_and_file_generator(path_raw_data, 
                                                       real=True,
                                                       simulated=False, 
                                                       drawn=False),
                              columns=['class_code', 'instance_path'])
real_instances = real_instances.loc[real_instances.iloc[:,0].isin(abnormal_classes_codes)].reset_index(drop=True)

# %%
# Gets all real instances but maintains only those with any type of undesirable event
draw_instances = pd.DataFrame(class_and_file_generator(path_raw_data, 
                                                       real=False,
                                                       simulated=True, 
                                                       drawn=False),
                              columns=['class_code', 'instance_path'])
draw_instances = draw_instances.loc[draw_instances.iloc[:,0].isin(abnormal_classes_codes)].reset_index(drop=True)

# %%
0 % 10
# Out:
# 0

# %%
#file_paths = real_instances[real_instances["class_code"] == falha]["instance_path"].values
df_output = pd.DataFrame()
qtde_segundos = 60 * 20
falhas = [1, 2, 5, 6, 7, 8, 101, 102, 105, 106, 107, 108]
for file_path in real_instances["instance_path"].values:
    df_data = pd.read_csv(file_path)

    df_data = FormatData.set_index_dataframe(df_data=df_data,
                                         column_name="timestamp")
    
    for falha in falhas:
        df_data['class'] = df_data['class'].replace(falha, 1)
    
    segundos = (df_data['class'] == 0).sum()

    quantidade = df_data['class'].isin(falhas).sum()
    if quantidade != 0:
        print(f"1 se repete {quantidade}")
        print(f"Index min {df_data.index.min()} index max {df_data.index.max()}")

        df_output = pd.concat([df_output, df_data], axis=0)
# Out:
# 1 se repete 14303
# Index min 2014-01-24 09:33:03 index max 2014-01-25 01:47:30
# 1 se repete 9499
# Index min 2014-01-26 16:19:44 index max 2014-01-26 23:00:00
# 1 se repete 40042
# Index min 2017-07-31 18:09:30 index max 2017-08-01 20:45:00
# 1 se repete 31658
# Index min 2017-07-31 22:04:32 index max 2017-08-01 20:19:27
# 1 se repete 10573
# Index min 2018-06-17 20:02:57 index max 2018-06-18 11:00:00
# 1 se repete 5306
# Index min 2013-11-04 01:41:01 index max 2013-11-04 04:13:01
# 1 se repete 3175
# Index min 2017-03-13 16:08:04 index max 2017-03-13 18:00:21
# 1 se repete 3863
# Index min 2017-12-18 19:01:31 index max 2017-12-18 21:44:59
# 1 se repete 20186
# Index min 2014-05-15 10:46:09 index max 2014-05-15 16:59:37
# 1 se repete 1490
# Index min 2014-05-30 09:32:03 index max 2014-05-30 10:33:14
# 1 se repete 11299
# Index min 2014-06-06 22:38:10 index max 2014-06-07 02:41:46
# 1 se repete 4901
# Index min 2014-07-20 12:01:02 index max 2014-07-20 15:20:12
# 1 se repete 2536
# Index min 2014-07-26 17:45:23 index max 2014-07-26 18:57:44
# 1 se repete 14956
# Index min 2014-08-24 00:01:18 index max 2014-08-24 05:00:00
# 1 se repete 1940
# Index min 2014-09-16 06:03:00 index max 2014-09-16 07:36:33
# 1 se repete 2024
# Index min 2014-09-21 19:32:28 index max 2014-09-21 20:45:54
# 1 se repete 1999
# Index min 2014-09-28 10:00:56 index max 2014-09-28 11:34:08
# 1 se repete 1716
# Index min 2014-09-29 16:33:32 index max 2014-09-29 17:45:29
# 1 se repete 1206
# Index min 2014-09-29 22:01:21 index max 2014-09-29 23:18:32
# 1 se repete 2910
# Index min 2014-10-05 17:00:56 index max 2014-10-05 18:26:10
# 1 se repete 1723
# Index min 2014-10-06 16:01:21 index max 2014-10-06 17:15:36
# 1 se repete 8959
# Index min 2017-06-20 04:05:30 index max 2017-06-20 19:23:52
# 1 se repete 2114
# Index min 2018-04-04 22:22:55 index max 2018-04-05 02:58:55
# 1 se repete 1104
# Index min 2018-04-26 10:25:31 index max 2018-04-26 14:44:04
# 1 se repete 2796
# Index min 2018-04-26 10:57:23 index max 2018-04-26 15:44:20
# 1 se repete 10461
# Index min 2018-05-17 18:45:36 index max 2018-05-18 01:42:55
# 1 se repete 138359
# Index min 2014-03-14 13:52:48 index max 2014-03-16 08:33:14
# 1 se repete 32072
# Index min 2014-03-17 12:34:19 index max 2014-03-18 01:30:00
# 1 se repete 39357
# Index min 2014-03-17 22:59:27 index max 2014-03-18 13:57:58
# 1 se repete 31870
# Index min 2014-03-18 13:06:03 index max 2014-03-19 02:00:00
# 1 se repete 17742
# Index min 2014-03-19 02:01:30 index max 2014-03-19 11:00:00
# 1 se repete 45762
# Index min 2014-03-19 03:16:16 index max 2014-03-20 04:20:38
# 1 se repete 9113
# Index min 2014-02-12 17:03:33 index max 2014-02-12 23:49:42
# 1 se repete 1515
# Index min 2014-03-01 15:17:00 index max 2014-03-01 18:28:17
# 1 se repete 6260
# Index min 2014-03-25 17:03:04 index max 2014-03-25 20:23:24
# 1 se repete 858
# Index min 2017-10-31 18:15:09 index max 2017-10-31 19:14:54
# 1 se repete 645
# Index min 2017-10-31 19:07:06 index max 2017-10-31 19:48:23
# 1 se repete 812
# Index min 2017-10-31 19:44:52 index max 2017-10-31 20:28:56
# 1 se repete 38817
# Index min 2017-02-26 14:01:46 index max 2017-02-27 10:18:58
# 1 se repete 127179
# Index min 2018-06-17 18:13:15 index max 2018-06-19 23:06:08
# 1 se repete 100242
# Index min 2018-06-20 15:57:28 index max 2018-06-21 23:56:30
# 1 se repete 25136
# Index min 2018-06-11 02:12:18 index max 2018-06-11 14:08:31
# 1 se repete 17758
# Index min 2019-04-03 02:33:07 index max 2019-04-03 15:00:00

# %%
#file_paths = draw_instances[draw_instances["class_code"] == falha]["instance_path"].values
df_draw = pd.DataFrame()
qtde_segundos = 60 * 20
falhas = [1, 2, 5, 6, 7, 8, 101, 102, 105, 106, 107, 108]
for file_path in draw_instances["instance_path"].values:
    df_data = pd.read_csv(file_path)

    df_data = FormatData.set_index_dataframe(df_data=df_data,
                                         column_name="timestamp")
    
    for falha in falhas:
        df_data['class'] = df_data['class'].replace(falha, 1)
    
    segundos = (df_data['class'] == 0).sum()

    quantidade = df_data['class'].isin(falhas).sum()
    if quantidade != 0:
        print(f"1 se repete {quantidade}")
        print(f"Index min {df_data.index.min()} index max {df_data.index.max()}")

        df_draw = pd.concat([df_draw, df_data], axis=0)
# Out:
# 1 se repete 159021
# Index min 2018-09-05 20:44:36 index max 2018-09-07 20:44:35
# 1 se repete 79511
# Index min 2018-09-05 20:44:36 index max 2018-09-06 20:44:35
# 1 se repete 19439
# Index min 2018-09-05 20:44:36 index max 2018-09-06 02:44:35
# 1 se repete 28508
# Index min 2018-09-05 20:44:36 index max 2018-09-06 08:44:35
# 1 se repete 12959
# Index min 2018-09-05 20:44:36 index max 2018-09-06 00:44:35
# 1 se repete 53570
# Index min 2018-09-05 20:44:36 index max 2018-09-06 20:44:35
# 1 se repete 41478
# Index min 2018-09-05 20:44:36 index max 2018-09-06 08:44:35
# 1 se repete 12959
# Index min 2018-09-05 20:44:36 index max 2018-09-06 00:44:35
# 1 se repete 20317
# Index min 2018-09-05 20:44:36 index max 2018-09-06 02:44:35
# 1 se repete 33710
# Index min 2018-09-05 20:44:36 index max 2018-09-06 08:44:35
# 1 se repete 304263
# Index min 2018-08-20 11:25:44 index max 2018-08-24 11:25:44
# 1 se repete 311012
# Index min 2018-08-20 11:25:44 index max 2018-08-24 11:25:44
# 1 se repete 318042
# Index min 2018-08-20 11:25:44 index max 2018-08-24 11:25:44
# 1 se repete 36311
# Index min 2018-08-20 11:25:44 index max 2018-08-20 23:25:44
# 1 se repete 311012
# Index min 2018-08-20 11:25:44 index max 2018-08-24 11:25:44
# 1 se repete 283454
# Index min 2018-08-20 11:25:44 index max 2018-08-24 11:25:44
# 1 se repete 311012
# Index min 2018-08-20 11:25:44 index max 2018-08-24 11:25:44
# 1 se repete 162537
# Index min 2018-08-20 11:25:44 index max 2018-08-22 11:25:44
# 1 se repete 36311
# Index min 2018-08-20 11:25:44 index max 2018-08-20 23:25:44
# 1 se repete 77753
# Index min 2018-08-20 11:25:44 index max 2018-08-21 11:25:44

# %%
df_output
# Out:
#                      P-PDG       P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP  \
# timestamp
# 2014-01-24 09:33:03    0.0  18433410.0  116.8718  9397031.0   74.80031
# 2014-01-24 09:33:04    0.0  18433410.0  116.8718  9397031.0   74.80031
# 2014-01-24 09:33:05    0.0  18433410.0  116.8718  9397032.0   74.80031
# 2014-01-24 09:33:06    0.0  18433410.0  116.8718  9397033.0   74.80031
# 2014-01-24 09:33:07    0.0  18433410.0  116.8718  9397033.0   74.80031
# ...                    ...         ...       ...        ...        ...
# 2019-04-03 14:59:56    0.0   8489354.0  109.7213  1496222.0   73.38219
# 2019-04-03 14:59:57    0.0   8489349.0  109.7212  1495828.0   73.38310
# 2019-04-03 14:59:58    0.0   8489344.0  109.7210  1495433.0   73.38401
# 2019-04-03 14:59:59    0.0   8489338.0  109.7209  1495039.0   73.38493
# 2019-04-03 15:00:00    0.0   8489333.0  109.7207  1494645.0   73.38583
#
#                      P-JUS-CKGL  T-JUS-CKGL  QGL  class
# timestamp
# 2014-01-24 09:33:03   -300917.8         NaN  0.0    0.0
# 2014-01-24 09:33:04   -300917.8         NaN  0.0    0.0
# 2014-01-24 09:33:05   -300917.8         NaN  0.0    0.0
# 2014-01-24 09:33:06   -300917.8         NaN  0.0    0.0
# 2014-01-24 09:33:07   -300917.8         NaN  0.0    0.0
# ...                         ...         ...  ...    ...
# 2019-04-03 14:59:56   9706965.0         NaN  0.0    1.0
# 2019-04-03 14:59:57   9706899.0         NaN  0.0    1.0
# 2019-04-03 14:59:58   9706834.0         NaN  0.0    1.0
# 2019-04-03 14:59:59   9706768.0         NaN  0.0    1.0
# 2019-04-03 15:00:00   9706702.0         NaN  0.0    1.0
#
# [1522298 rows x 9 columns]

# %%
df_draw
# Out:
#                         P-PDG     P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP  \
# timestamp
# 2018-09-05 20:44:36  420.2314  175.3406  114.8907   96.64524   66.75450
# 2018-09-05 20:44:37  420.2314  175.3406  114.8907   96.64524   66.75450
# 2018-09-05 20:44:38  420.2314  175.3406  114.8907   96.64524   66.75450
# 2018-09-05 20:44:39  420.2314  175.3406  114.8907   96.64524   66.75450
# 2018-09-05 20:44:40  420.2314  175.3406  114.8907   96.64524   66.75450
# ...                       ...       ...       ...        ...        ...
# 2018-08-21 11:25:40  260.9383  211.8869  117.8766  122.91520   65.02185
# 2018-08-21 11:25:41  260.9383  211.8869  117.8766  122.91520   65.02185
# 2018-08-21 11:25:42  260.9383  211.8869  117.8766  122.91520   65.02185
# 2018-08-21 11:25:43  260.9383  211.8869  117.8766  122.91520   65.02185
# 2018-08-21 11:25:44  260.9383  211.8869  117.8766  122.91520   65.02185
#
#                      P-JUS-CKGL  T-JUS-CKGL  QGL  class
# timestamp
# 2018-09-05 20:44:36         NaN         NaN  NaN      0
# 2018-09-05 20:44:37         NaN         NaN  NaN      0
# 2018-09-05 20:44:38         NaN         NaN  NaN      0
# 2018-09-05 20:44:39         NaN         NaN  NaN      0
# 2018-09-05 20:44:40         NaN         NaN  NaN      0
# ...                         ...         ...  ...    ...
# 2018-08-21 11:25:40         NaN         NaN  NaN      1
# 2018-08-21 11:25:41         NaN         NaN  NaN      1
# 2018-08-21 11:25:42         NaN         NaN  NaN      1
# 2018-08-21 11:25:43         NaN         NaN  NaN      1
# 2018-08-21 11:25:44         NaN         NaN  NaN      1
#
# [2966410 rows x 9 columns]

# %%
df_output = df_output[~df_output.index.duplicated()]

# %%
df_draw = df_draw[~df_draw.index.duplicated()]

# %%
df_output.shape
# Out:
# (1334120, 9)

# %%
df_draw.shape
# Out:
# (518401, 9)

# %%
df_aux = df_output.drop(columns=["QGL", "T-JUS-CKGL", "P-JUS-CKGL"])
df_aux
# Out:
#                      P-PDG       P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP  class
# timestamp
# 2014-01-24 09:33:03    0.0  18433410.0  116.8718  9397031.0   74.80031    0.0
# 2014-01-24 09:33:04    0.0  18433410.0  116.8718  9397031.0   74.80031    0.0
# 2014-01-24 09:33:05    0.0  18433410.0  116.8718  9397032.0   74.80031    0.0
# 2014-01-24 09:33:06    0.0  18433410.0  116.8718  9397033.0   74.80031    0.0
# 2014-01-24 09:33:07    0.0  18433410.0  116.8718  9397033.0   74.80031    0.0
# ...                    ...         ...       ...        ...        ...    ...
# 2019-04-03 14:59:56    0.0   8489354.0  109.7213  1496222.0   73.38219    1.0
# 2019-04-03 14:59:57    0.0   8489349.0  109.7212  1495828.0   73.38310    1.0
# 2019-04-03 14:59:58    0.0   8489344.0  109.7210  1495433.0   73.38401    1.0
# 2019-04-03 14:59:59    0.0   8489338.0  109.7209  1495039.0   73.38493    1.0
# 2019-04-03 15:00:00    0.0   8489333.0  109.7207  1494645.0   73.38583    1.0
#
# [1334120 rows x 6 columns]

# %%
df_aux_draw = df_draw.drop(columns=["QGL", "T-JUS-CKGL", "P-JUS-CKGL"])
df_aux_draw
# Out:
#                         P-PDG     P-TPT      T-TPT  P-MON-CKP  T-JUS-CKP  \
# timestamp
# 2018-09-05 20:44:36  420.2314  175.3406  114.89070   96.64524   66.75450
# 2018-09-05 20:44:37  420.2314  175.3406  114.89070   96.64524   66.75450
# 2018-09-05 20:44:38  420.2314  175.3406  114.89070   96.64524   66.75450
# 2018-09-05 20:44:39  420.2314  175.3406  114.89070   96.64524   66.75450
# 2018-09-05 20:44:40  420.2314  175.3406  114.89070   96.64524   66.75450
# ...                       ...       ...        ...        ...        ...
# 2018-08-24 11:25:40  251.8535  139.0000   59.08355   19.22864   54.13496
# 2018-08-24 11:25:41  251.8535  139.0000   59.08355   19.22868   54.13496
# 2018-08-24 11:25:42  251.8535  139.0000   59.08355   19.22872   54.13496
# 2018-08-24 11:25:43  251.8535  139.0000   59.08355   19.22875   54.13496
# 2018-08-24 11:25:44  251.8535  139.0000   59.08355   19.22879   54.13496
#
#                      class
# timestamp
# 2018-09-05 20:44:36      0
# 2018-09-05 20:44:37      0
# 2018-09-05 20:44:38      0
# 2018-09-05 20:44:39      0
# 2018-09-05 20:44:40      0
# ...                    ...
# 2018-08-24 11:25:40      1
# 2018-08-24 11:25:41      1
# 2018-08-24 11:25:42      1
# 2018-08-24 11:25:43      1
# 2018-08-24 11:25:44      1
#
# [518401 rows x 6 columns]

# %%
for column_name in df_aux.columns:
    percent = Preprocessing.check_null_dataframe(df_data=df_aux, column_name=column_name)
    print(f"{column_name} null data is {percent}")
# Out:
# P-PDG null data is 0.26414415494858035
# P-TPT null data is 8.322489731058676
# T-TPT null data is 8.322189907954307
# P-MON-CKP null data is 8.322789554163043
# T-JUS-CKP null data is 8.322789554163043
# class null data is 6.438401343207508

# %%
for column_name in df_aux_draw.columns:
    percent = Preprocessing.check_null_dataframe(df_data=df_aux_draw, column_name=column_name)
    print(f"{column_name} null data is {percent}")
# Out:
# P-PDG null data is 0.0
# P-TPT null data is 0.0
# T-TPT null data is 0.0
# P-MON-CKP null data is 0.0
# T-JUS-CKP null data is 0.0
# class null data is 0.0

# %%
df_aux = df_aux.dropna()
df_aux.shape
# Out:
# (1139181, 6)

# %%
df_aux_draw = df_aux_draw.dropna()
df_aux_draw.shape
# Out:
# (518401, 6)

# %%
df_aux = df_aux.drop_duplicates()
df_aux_draw = df_aux_draw.drop_duplicates()

# %%
contagem_classes = df_aux['class'].value_counts()

# Calcular a porcentagem de cada classe
porcentagem_classes_real = contagem_classes / len(df_aux) * 100
porcentagem_classes_real
# Out:
# class
# 1.0    65.880605
# 0.0    34.119395
# Name: count, dtype: float64

# %%
contagem_classes = df_aux_draw['class'].value_counts()

# Calcular a porcentagem de cada classe
porcentagem_classes_draw = contagem_classes / len(df_aux_draw) * 100
porcentagem_classes_draw
# Out:
# class
# 1    96.830891
# 0     3.169109
# Name: count, dtype: float64

# %% [markdown]
# Aqui é possível ver que tem poquíssimas classes normais!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# # MLP

# %%
df_aux["class"].unique()
# Out:
# array([0., 1.])

# %%
# Separar as features (X) e os rótulos (y)
X = df_aux.drop('class', axis=1)
y = df_aux['class']

# %%
X
# Out:
#                      P-PDG       P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP
# timestamp
# 2014-01-24 09:33:03    0.0  18433410.0  116.8718  9397031.0   74.80031
# 2014-01-24 09:33:05    0.0  18433410.0  116.8718  9397032.0   74.80031
# 2014-01-24 09:33:06    0.0  18433410.0  116.8718  9397033.0   74.80031
# 2014-01-24 09:33:08    0.0  18433410.0  116.8718  9397034.0   74.80031
# 2014-01-24 09:33:10    0.0  18433410.0  116.8718  9397035.0   74.80031
# ...                    ...         ...       ...        ...        ...
# 2019-04-03 14:59:56    0.0   8489354.0  109.7213  1496222.0   73.38219
# 2019-04-03 14:59:57    0.0   8489349.0  109.7212  1495828.0   73.38310
# 2019-04-03 14:59:58    0.0   8489344.0  109.7210  1495433.0   73.38401
# 2019-04-03 14:59:59    0.0   8489338.0  109.7209  1495039.0   73.38493
# 2019-04-03 15:00:00    0.0   8489333.0  109.7207  1494645.0   73.38583
#
# [1129428 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, stratify=y_train, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)

X_test = scaler.transform(X_test)

# %%
# Defina o modelo
model = Sequential()

# Adicione as camadas ocultas
model.add(Dense(8, input_dim=5, activation='relu'))  # Camada de entrada com 4 neurônios e ativação ReLU
model.add(Dense(4, activation='relu'))  # Segunda camada oculta com 4 neurônios e ativação ReLU

# Adicione a camada de saída
model.add(Dense(1, activation='sigmoid'))  # Camada de saída com 1 neurônio e ativação Sigmoid para classificação binária

# Compile o modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Treine o modelo
model.fit(X_train, y_train, epochs=100, batch_size=10, validation_data=(X_val, y_val))

# Avalie o modelo
_, accuracy = model.evaluate(X_test, y_test)
print('Acurácia: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 55342/55342 [==============================] - 65s 1ms/step - loss: 0.4454 - accuracy: 0.7770 - val_loss: 0.3868 - val_accuracy: 0.8158
# Epoch 2/100
# 55342/55342 [==============================] - 66s 1ms/step - loss: 0.3703 - accuracy: 0.8298 - val_loss: 0.3647 - val_accuracy: 0.8351
# Epoch 3/100
# 55342/55342 [==============================] - 65s 1ms/step - loss: 0.3513 - accuracy: 0.8365 - val_loss: 0.3421 - val_accuracy: 0.8349
# Epoch 4/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.3324 - accuracy: 0.8446 - val_loss: 0.3392 - val_accuracy: 0.8025
# Epoch 5/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.3128 - accuracy: 0.8471 - val_loss: 0.3043 - val_accuracy: 0.8513
# Epoch 6/100
# 55342/55342 [==============================] - 63s 1ms/step - loss: 0.3038 - accuracy: 0.8505 - val_loss: 0.3024 - val_accuracy: 0.8593
# Epoch 7/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2890 - accuracy: 0.8582 - val_loss: 0.2772 - val_accuracy: 0.8653
# Epoch 8/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2748 - accuracy: 0.8652 - val_loss: 0.2638 - val_accuracy: 0.8734
# Epoch 9/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2701 - accuracy: 0.8668 - val_loss: 0.2604 - val_accuracy: 0.8749
# Epoch 10/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2671 - accuracy: 0.8681 - val_loss: 0.2652 - val_accuracy: 0.8713
# Epoch 11/100
# 55342/55342 [==============================] - 72s 1ms/step - loss: 0.2646 - accuracy: 0.8697 - val_loss: 0.2637 - val_accuracy: 0.8720
# Epoch 12/100
# 55342/55342 [==============================] - 65s 1ms/step - loss: 0.2621 - accuracy: 0.8715 - val_loss: 0.2619 - val_accuracy: 0.8797
# Epoch 13/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2560 - accuracy: 0.8759 - val_loss: 0.2424 - val_accuracy: 0.8970
# Epoch 14/100
# 55342/55342 [==============================] - 63s 1ms/step - loss: 0.2369 - accuracy: 0.8955 - val_loss: 0.2222 - val_accuracy: 0.9105
# Epoch 15/100
# 55342/55342 [==============================] - 66s 1ms/step - loss: 0.2240 - accuracy: 0.9023 - val_loss: 0.2226 - val_accuracy: 0.9037
# Epoch 16/100
# 55342/55342 [==============================] - 61s 1ms/step - loss: 0.2189 - accuracy: 0.9046 - val_loss: 0.2244 - val_accuracy: 0.9006
# Epoch 17/100
# 55342/55342 [==============================] - 63s 1ms/step - loss: 0.2166 - accuracy: 0.9059 - val_loss: 0.2127 - val_accuracy: 0.9148
# Epoch 18/100
# 55342/55342 [==============================] - 67s 1ms/step - loss: 0.2150 - accuracy: 0.9069 - val_loss: 0.2075 - val_accuracy: 0.9173
# Epoch 19/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2141 - accuracy: 0.9076 - val_loss: 0.2140 - val_accuracy: 0.9023
# Epoch 20/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2131 - accuracy: 0.9074 - val_loss: 0.2115 - val_accuracy: 0.9121
# Epoch 21/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2122 - accuracy: 0.9082 - val_loss: 0.2088 - val_accuracy: 0.9070
# Epoch 22/100
# 55342/55342 [==============================] - 64s 1ms/step - loss: 0.2114 - accuracy: 0.9088 - val_loss: 0.2091 - val_accuracy: 0.9189
# Epoch 23/100
# 36361/55342 [==================>...........] - ETA: 17s - loss: 0.2108 - accuracy: 0.9090
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 15
#      12 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#      14 # Treine o modelo
# ---> 15 model.fit(X_train, y_train, epochs=100, batch_size=10, validation_data=(X_val, y_val))
#      17 # Avalie o modelo
#      18 _, accuracy = model.evaluate(X_test, y_test)
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
y_pred = model.predict(X_test)
# Out:
# 10589/10589 [==============================] - 7s 694us/step

# %%
y_pred = np.squeeze(y_pred)
y_pred = np.where(y_pred > 0.5, 1, 0)

# %%
accuracy_score(y_test.values, y_pred)
# Out:
# 0.9135817772386661

# %%
precision = precision_score(y_test.values, y_pred, average=None)
recall = recall_score(y_test.values, y_pred, average=None)
f1 = f1_score(y_test.values, y_pred, average=None)

# %%
for i in range(len(precision)):
    print(f'Classe {porcentagem_classes_real.index.values[i]}:')
    print(f'Precision: {precision[i]}')
    print(f'Recall: {recall[i]}')
    print(f'F1-score: {f1[i]}\n')
# Out:
# Classe 1.0:
# Precision: 0.8734652557258183
# Recall: 0.8732159230489767
# F1-score: 0.8733405715917102
#
# Classe 0.0:
# Precision: 0.9343489088759093
# Recall: 0.9344870376260511
# F1-score: 0.9344179681463182

# %%
# Separar as features (X) e os rótulos (y)
X = df_aux_draw.drop('class', axis=1)
y_test = df_aux_draw['class']

X_norm = scaler.transform(X.values)

y_pred = model.predict(X_norm)

y_pred = np.squeeze(y_pred)
y_pred = np.where(y_pred > 0.5, 1, 0)

print(accuracy_score(y_test, y_pred))

precision = precision_score(y_test, y_pred, average=None)
recall = recall_score(y_test, y_pred, average=None)
f1 = f1_score(y_test, y_pred, average=None)

unique_y_pred = np.unique(y_pred)
unique_y_test = np.unique(y_test)

result_array = np.sort(np.unique(np.concatenate((unique_y_pred, unique_y_test))))

for i in range(len(precision)):
    print(f'Classe {result_array[i]}:')
    print(f'Precision: {precision[i]}')
    print(f'Recall: {recall[i]}')
    print(f'F1-score: {f1[i]}\n')
# Out:
#   150/12297 [..............................] - ETA: 8s
# c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 12297/12297 [==============================] - 8s 683us/step
# 0.8808801329653406
# Classe 0:
# Precision: 0.09200664136622391
# Recall: 0.3110665597433841
# F1-score: 0.14200988467874795
#
# Classe 1:
# Precision: 0.9755469279244918
# Recall: 0.8995291536313436
# F1-score: 0.9359971161014935

# %%
X = df_aux_draw[df_aux_draw["class"] == 7].drop('class', axis=1)
df_aux_draw[df_aux_draw["class"] == 7].drop('class', axis=1)

y_test = df_aux_draw[df_aux_draw["class"] == 7]["class"]

X_norm = scaler.transform(X.values)

y_pred = modelo.predict(X_norm)
# Out:
# c:\Users\marce\Documents\0_python_env\venv3WPetrobras\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([5., 5., 5., ..., 5., 5., 5.])

# %% [markdown]
# está prevendo todo mundo da classe 7 como a classe 5

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.0
