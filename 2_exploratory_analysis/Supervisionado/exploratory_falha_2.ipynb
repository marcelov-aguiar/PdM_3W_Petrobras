# %%
import pandas as pd
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import dill
from typing import List
import scipy.stats as sts
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

import util
from pathlib import Path
from class_manipulates_path import ManipulatePath
from class_preprocessing_refactor import Preprocessing
from class_format_data import FormatData
util.init()

current_path = sys.path[0]

# %%
def plot_variable(df, column_name, intervalos=None):
    """
    Plota um gráfico de dispersão para uma variável de um DataFrame.

    Parâmetros:
        - df: DataFrame pandas contendo os dados.
        - column_name: Nome da coluna que você deseja plotar.
        - intervalos: Lista de intervalos para plotar linhas verticais.
    """
    plt.figure(figsize=(20, 10))
    plt.scatter(df.index.values, df[column_name].values, color='darkcyan', alpha=0.5)
    plt.xlabel('Índice')
    plt.ylabel(column_name)
    plt.title(f'Gráfico de dispersão para a variável "{column_name}"')


    # Plotar linhas verticais para cada intervalo
    if intervalos:
        for intervalo in intervalos:
            plt.axvline(x=intervalo, linestyle='--', color='red')

    plt.show()

# %%
def class_and_file_generator(data_path, real=False, simulated=False, drawn=False):
    for class_path in data_path.iterdir():
        if class_path.is_dir():
            class_code = int(class_path.stem)
            for instance_path in class_path.iterdir():
                if (instance_path.suffix == '.csv'):
                    if (simulated and instance_path.stem.startswith('SIMULATED')) or \
                       (drawn and instance_path.stem.startswith('DRAWN')) or \
                       (real and (not instance_path.stem.startswith('SIMULATED')) and \
                       (not instance_path.stem.startswith('DRAWN'))):
                        yield class_code, instance_path

# %%
manipulate_path = ManipulatePath()

preprocessing = Preprocessing()

format_data = FormatData()

path_raw_data = manipulate_path.get_path_raw_data()

abnormal_classes_codes = [1, 2, 5, 6, 7, 8]

# %%
# Gets all real instances but maintains only those with any type of undesirable event
real_instances = pd.DataFrame(class_and_file_generator(path_raw_data, 
                                                       real=True,
                                                       simulated=True, 
                                                       drawn=True),
                              columns=['class_code', 'instance_path'])
real_instances = real_instances.loc[real_instances.iloc[:,0].isin(abnormal_classes_codes)].reset_index(drop=True)

# %%
falha = 2
falha_2 = 102

# %%
real_instances[real_instances["class_code"] == falha]
# Out:
#      class_code                                      instance_path
# 129           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 130           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 131           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 132           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 133           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 134           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 135           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 136           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 137           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 138           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 139           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 140           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 141           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 142           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 143           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 144           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 145           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 146           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 147           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 148           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 149           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 150           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 151           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 152           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 153           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 154           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 155           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 156           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 157           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 158           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 159           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 160           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 161           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 162           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 163           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 164           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 165           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...
# 166           2  c:\Users\marce\Documents\MEGA\0_PUC-Rio\2_Peri...

# %%
real_instances[real_instances["class_code"] == falha]["instance_path"].values
# Out:
# array([WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00001.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00002.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00003.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00004.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00005.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00006.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00007.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00008.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00009.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00010.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00011.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00012.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00013.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00014.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00015.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/SIMULATED_00016.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00002_20131104014101.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00003_20141122200000.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00003_20170728140240.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00003_20180206181001.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00009_20170313160804.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00010_20171218190131.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140515104609.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140530093203.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140606223810.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140720120102.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140726174523.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140824000118.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140916060300.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140921193228.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140928100056.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140929163332.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20140929220121.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20141005170056.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00011_20141006160121.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00012_20170320021000.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00012_20170320133144.csv'),
#        WindowsPath('c:/Users/marce/Documents/MEGA/0_PUC-Rio/2_Periodo/2_Data_Science/2_Trabalho_Final/3_3W/1_data/1_raw_data/2/WELL-00013_20170329020229.csv')],
#       dtype=object)

# %%
file_paths = real_instances[real_instances["class_code"] == falha]["instance_path"].values
df_output = pd.DataFrame()

for file_path in file_paths:
    df_data = pd.read_csv(file_path)

    df_data = FormatData.set_index_dataframe(df_data=df_data,
                                         column_name="timestamp")
    quantidade = ((df_data['class'] == falha) | (df_data['class'] == falha_2)).sum()
    if quantidade != 0:
        print(f"1 se repete {quantidade}")
        print(f"Index min {df_data.index.min()} index max {df_data.index.max()}")

    df_output = pd.concat([df_output, df_data], axis=0)
# Out:
# 1 se repete 25199
# Index min 2018-05-13 01:53:17 index max 2018-05-13 09:53:15
# 1 se repete 25199
# Index min 2018-05-13 02:09:15 index max 2018-05-13 10:09:13
# 1 se repete 25199
# Index min 2018-05-13 02:57:51 index max 2018-05-13 10:57:49
# 1 se repete 25199
# Index min 2018-05-13 03:20:31 index max 2018-05-13 11:20:29
# 1 se repete 25199
# Index min 2018-05-13 03:40:55 index max 2018-05-13 11:40:53
# 1 se repete 25199
# Index min 2018-05-13 03:56:05 index max 2018-05-13 11:56:03
# 1 se repete 25199
# Index min 2018-05-13 04:10:32 index max 2018-05-13 12:10:30
# 1 se repete 25199
# Index min 2018-05-13 04:29:29 index max 2018-05-13 12:29:27
# 1 se repete 25199
# Index min 2018-05-13 04:49:38 index max 2018-05-13 12:49:36
# 1 se repete 25199
# Index min 2018-05-13 05:12:11 index max 2018-05-13 13:12:09
# 1 se repete 25199
# Index min 2018-05-13 05:30:09 index max 2018-05-13 13:30:07
# 1 se repete 25199
# Index min 2018-05-13 05:47:27 index max 2018-05-13 13:47:25
# 1 se repete 25199
# Index min 2018-05-13 06:20:06 index max 2018-05-13 14:20:04
# 1 se repete 25199
# Index min 2018-05-13 06:35:03 index max 2018-05-13 14:35:01
# 1 se repete 25199
# Index min 2018-05-13 06:56:53 index max 2018-05-13 14:56:51
# 1 se repete 25199
# Index min 2018-05-13 07:34:43 index max 2018-05-13 15:34:41
# 1 se repete 5306
# Index min 2013-11-04 01:41:01 index max 2013-11-04 04:13:01
# 1 se repete 3175
# Index min 2017-03-13 16:08:04 index max 2017-03-13 18:00:21
# 1 se repete 3863
# Index min 2017-12-18 19:01:31 index max 2017-12-18 21:44:59
# 1 se repete 20186
# Index min 2014-05-15 10:46:09 index max 2014-05-15 16:59:37
# 1 se repete 1490
# Index min 2014-05-30 09:32:03 index max 2014-05-30 10:33:14
# 1 se repete 11299
# Index min 2014-06-06 22:38:10 index max 2014-06-07 02:41:46
# 1 se repete 4901
# Index min 2014-07-20 12:01:02 index max 2014-07-20 15:20:12
# 1 se repete 2536
# Index min 2014-07-26 17:45:23 index max 2014-07-26 18:57:44
# 1 se repete 14956
# Index min 2014-08-24 00:01:18 index max 2014-08-24 05:00:00
# 1 se repete 1940
# Index min 2014-09-16 06:03:00 index max 2014-09-16 07:36:33
# 1 se repete 2024
# Index min 2014-09-21 19:32:28 index max 2014-09-21 20:45:54
# 1 se repete 1999
# Index min 2014-09-28 10:00:56 index max 2014-09-28 11:34:08
# 1 se repete 1716
# Index min 2014-09-29 16:33:32 index max 2014-09-29 17:45:29
# 1 se repete 1206
# Index min 2014-09-29 22:01:21 index max 2014-09-29 23:18:32
# 1 se repete 2910
# Index min 2014-10-05 17:00:56 index max 2014-10-05 18:26:10
# 1 se repete 1723
# Index min 2014-10-06 16:01:21 index max 2014-10-06 17:15:36

# %%
df_output
# Out:
#                           P-PDG       P-TPT       T-TPT  P-MON-CKP  T-JUS-CKP  \
# timestamp
# 2018-05-13 01:53:17  27840330.0  20228170.0  124.573200  4065790.0   90.81752
# 2018-05-13 01:53:18  27840590.0  20228170.0  124.573200  4065790.0   90.81752
# 2018-05-13 01:53:19  27840330.0  20228170.0  124.573200  4065790.0   90.81753
# 2018-05-13 01:53:20  27840590.0  20228170.0  124.573200  4065790.0   90.81753
# 2018-05-13 01:53:21  27840330.0  20228170.0  124.573200  4065790.0   90.81753
# ...                         ...         ...         ...        ...        ...
# 2017-03-29 04:52:42         0.0  10763410.0    8.439219        NaN        NaN
# 2017-03-29 04:52:43         0.0  10764910.0    8.437844        NaN        NaN
# 2017-03-29 04:52:44         0.0  10766400.0    8.436469        NaN        NaN
# 2017-03-29 04:52:45         0.0  10767900.0    8.435095        NaN        NaN
# 2017-03-29 04:52:46         0.0  10769400.0    8.433720        NaN        NaN
#
#                      P-JUS-CKGL  T-JUS-CKGL  QGL  class
# timestamp
# 2018-05-13 01:53:17         NaN         NaN  NaN    0.0
# 2018-05-13 01:53:18         NaN         NaN  NaN    0.0
# 2018-05-13 01:53:19         NaN         NaN  NaN    0.0
# 2018-05-13 01:53:20         NaN         NaN  NaN    0.0
# 2018-05-13 01:53:21         NaN         NaN  NaN    0.0
# ...                         ...         ...  ...    ...
# 2017-03-29 04:52:42         NaN         NaN  2.0    NaN
# 2017-03-29 04:52:43         NaN         NaN  2.0    NaN
# 2017-03-29 04:52:44         NaN         NaN  2.0    NaN
# 2017-03-29 04:52:45         NaN         NaN  2.0    NaN
# 2017-03-29 04:52:46         NaN         NaN  2.0    NaN
#
# [655017 rows x 9 columns]

# %%
df_output = df_output[~df_output.index.duplicated()]

# %%
df_output.shape
# Out:
# (243518, 9)

# %%
df_aux = df_output.drop(columns=["QGL", "T-JUS-CKGL"])
df_aux
# Out:
#                           P-PDG       P-TPT       T-TPT  P-MON-CKP  T-JUS-CKP  \
# timestamp
# 2018-05-13 01:53:17  27840330.0  20228170.0  124.573200  4065790.0   90.81752
# 2018-05-13 01:53:18  27840590.0  20228170.0  124.573200  4065790.0   90.81752
# 2018-05-13 01:53:19  27840330.0  20228170.0  124.573200  4065790.0   90.81753
# 2018-05-13 01:53:20  27840590.0  20228170.0  124.573200  4065790.0   90.81753
# 2018-05-13 01:53:21  27840330.0  20228170.0  124.573200  4065790.0   90.81753
# ...                         ...         ...         ...        ...        ...
# 2017-03-29 04:52:42         0.0  10763410.0    8.439219        NaN        NaN
# 2017-03-29 04:52:43         0.0  10764910.0    8.437844        NaN        NaN
# 2017-03-29 04:52:44         0.0  10766400.0    8.436469        NaN        NaN
# 2017-03-29 04:52:45         0.0  10767900.0    8.435095        NaN        NaN
# 2017-03-29 04:52:46         0.0  10769400.0    8.433720        NaN        NaN
#
#                      P-JUS-CKGL  class
# timestamp
# 2018-05-13 01:53:17         NaN    0.0
# 2018-05-13 01:53:18         NaN    0.0
# 2018-05-13 01:53:19         NaN    0.0
# 2018-05-13 01:53:20         NaN    0.0
# 2018-05-13 01:53:21         NaN    0.0
# ...                         ...    ...
# 2017-03-29 04:52:42         NaN    NaN
# 2017-03-29 04:52:43         NaN    NaN
# 2017-03-29 04:52:44         NaN    NaN
# 2017-03-29 04:52:45         NaN    NaN
# 2017-03-29 04:52:46         NaN    NaN
#
# [243518 rows x 7 columns]

# %%
for column_name in df_aux.columns:
    percent = Preprocessing.check_null_dataframe(df_data=df_output, column_name=column_name)
    print(f"{column_name} null data is {percent}")
# Out:
# P-PDG null data is 0.632807431072857
# P-TPT null data is 44.78067329725113
# T-TPT null data is 44.78067329725113
# P-MON-CKP null data is 48.97666702256096
# T-JUS-CKP null data is 69.22075575522138
# P-JUS-CKGL null data is 89.45950607347301
# class null data is 25.043733933425866

# %%
df_aux = df_aux.dropna()
df_aux.shape
# Out:
# (25528, 7)

# %%
(df_aux['class'] == 0).sum() / df_aux.shape[0]
# Out:
# 0.5164525227201504

# %% [markdown]
# # KNN

# %%
contagem_classes = df_aux['class'].value_counts()

# Calcular a porcentagem de cada classe
porcentagem_classes = contagem_classes / len(df_aux) * 100
porcentagem_classes
# Out:
# class
# 0.0      51.645252
# 102.0    36.458007
# 2.0      11.896741
# Name: count, dtype: float64

# %%
# Separar as features (X) e os rótulos (y)
X = df_aux.drop('class', axis=1)
y = df_aux['class']

# %%
X
# Out:
#                           P-PDG       P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP  \
# timestamp
# 2013-11-04 01:41:01         0.0  18852350.0  116.7782  9599435.0  173.09610
# 2013-11-04 01:41:02         0.0  18852350.0  116.7781  9599434.0  173.09610
# 2013-11-04 01:41:03         0.0  18852350.0  116.7780  9599432.0  173.09610
# 2013-11-04 01:41:04         0.0  18852350.0  116.7779  9599431.0  173.09610
# 2013-11-04 01:41:05         0.0  18852350.0  116.7779  9599429.0  173.09610
# ...                         ...         ...       ...        ...        ...
# 2017-12-18 21:44:55  22590210.0   5651389.0    7.8740  2394840.0   27.79927
# 2017-12-18 21:44:56  22589790.0   5713441.0    7.9350  2391128.0   27.76826
# 2017-12-18 21:44:57  22589370.0   5775494.0    7.9960  2387416.0   27.73725
# 2017-12-18 21:44:58  22588950.0   5659432.0    7.6340  2383704.0   27.70623
# 2017-12-18 21:44:59  22588530.0   5543370.0    7.2720  2379991.0   27.67522
#
#                        P-JUS-CKGL
# timestamp
# 2013-11-04 01:41:01  2.902859e+06
# 2013-11-04 01:41:02  2.902867e+06
# 2013-11-04 01:41:03  2.902875e+06
# 2013-11-04 01:41:04  2.902882e+06
# 2013-11-04 01:41:05  2.902890e+06
# ...                           ...
# 2017-12-18 21:44:55  1.630653e+09
# 2017-12-18 21:44:56  1.630483e+09
# 2017-12-18 21:44:57  1.630314e+09
# 2017-12-18 21:44:58  1.630144e+09
# 2017-12-18 21:44:59  1.629974e+09
#
# [25528 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
modelo = KNeighborsClassifier(n_neighbors=5)

# %%
modelo.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = modelo.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9988249118683902

# %%
precision = precision_score(y_test,  y_pred, average=None)
recall = recall_score(y_test,  y_pred, average=None)
f1 = f1_score(y_test,  y_pred, average=None)

for i in range(len(precision)):
    print(f'Classe {porcentagem_classes.index.values[i]}:')
    print(f'Precision: {precision[i]:.3f}')
    print(f'Recall: {recall[i]:.3f}')
    print(f'F1-score: {f1[i]:.3f}\n')
# Out:
# Classe 0.0:
# Precision: 1.000
# Recall: 1.000
# F1-score: 1.000
#
# Classe 102.0:
# Precision: 0.996
# Recall: 0.995
# F1-score: 0.995
#
# Classe 2.0:
# Precision: 0.998
# Recall: 0.999
# F1-score: 0.998

# %%
confusion_matrix(y_test.values, y_pred)
# Out:
# array([[3956,    0,    0],
#        [   0,  906,    5],
#        [   0,    4, 2788]], dtype=int64)

# %% [markdown]
# # MLP

# %%
modelo = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=42)

# %%
modelo.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=42)

# %%
y_pred = modelo.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9967358663010837
